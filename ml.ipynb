# %% [markdown]
# # ML

# %%
import pandas as pd
import matplotlib.pyplot as plt
import tkinter as tk
import numpy as np
from skimpy import skim
import skimpy
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
pd.set_option('display.max_columns', None)

# %%
data = 'C://Users//eduar//Desktop//DEV//Football//MLS//database.csv'
database = pd.read_csv(data)
database_ml = round(database.groupby('Jogador').agg({'Jogador': 'count'}),2)
database_ml.rename(columns={'Jogador':'Nº de Jogos'}, inplace= True)
database_ml.sort_values(by='Nº de Jogos', ascending= False, inplace= True)
database_ml = database_ml[database_ml['Nº de Jogos']>6].index
database_ml = database[database['Jogador'].isin(database_ml)]

# %%
database_ml.tail()
# Out:
#                  Jogador          Time   # Nação Pos.   Idade  Min.  Gols  \
# 12827    Ashley Westwood  Charlotte FC   8   ENG   DM  34-170    90     0
# 12828        Jere Uronen  Charlotte FC  21   FIN   LB  30-067    90     0
# 12830    Adilson Malanda  Charlotte FC  29   FRA   CB  22-325    90     0
# 12831       Nathan Byrne  Charlotte FC  14   ENG   RB  32-105    90     0
# 12832  Kristijan Kahlina  Charlotte FC   1   CRO   GK  32-056    90     0
#
#        Assis.  PB  PT  TC  CaG  CrtsA  CrtV  Contatos  Div  Crts  Bloqueios  \
# 12827       0   0   0   0    0      0     0        50    0     1          1
# 12828       0   0   0   0    0      0     0        61    1     1          1
# 12830       0   0   0   0    0      0     0        59    0     3          0
# 12831       0   0   0   0    0      0     0        63    0     1          1
# 12832       0   0   0   0    0      0     0        27    0     0          0
#
#         xG  npxG  xAG  SCA  GCA  Cmp  Att  Cmp%  PrgP  Conduções  PrgC  Tent  \
# 12827  0.0   0.0  0.0    2    0   34   45  75,6     5         34     0     0
# 12828  0.0   0.0  0.0    0    0   47   54  87,0     5         24     1     0
# 12830  0.0   0.0  0.0    0    0   47   51  92,2     6         37     0     0
# 12831  0.0   0.0  0.1    2    0   46   58  79,3     2         45     0     0
# 12832  0.0   0.0  0.0    0    0   14   25  56,0     0         15     0     0
#
#        Suc        Data
# 12827    0  2024-09-18
# 12828    0  2024-09-18
# 12830    0  2024-09-18
# 12831    0  2024-09-18
# 12832    0  2024-09-18

# %% [markdown]
# # Agrupado por Jogador

# %%
# Agrupar os dados por jogador e equipe, e calcular as somas e contagens necessárias
db_agrupado = database.groupby(['Jogador', 'Equipe']).agg(
    Total_Gols=('Gols', 'sum'),           # Soma de gols
    Total_Chutes=('TC', 'sum'),           # Soma dos chutes totais (presumo que TC significa 'Total Chutes')
    Aparicoes=('Jogador', 'count'),       # Contagem de aparições
    Total_Chutes_Gol=('CaG', 'sum')       # Soma dos chutes ao gol (CaG = Chutes ao Gol)
)

# Calcular as médias: chute total, chute ao gol e gols por aparição
db_agrupado['Média_Chutes_Total'] = round(db_agrupado['Total_Chutes'] / db_agrupado['Aparicoes'], 2)
db_agrupado['Média_Chutes_Gol'] = round(db_agrupado['Total_Chutes_Gol'] / db_agrupado['Aparicoes'], 2)
db_agrupado['Média_Gols'] = round(db_agrupado['Total_Gols'] / db_agrupado['Aparicoes'], 2)

# Ordenar o DataFrame pela média de chutes ao gol, de forma decrescente
db_agrupado.sort_values(by='Média_Chutes_Gol', ascending=False, inplace=True)

# Resetar o índice para que 'Jogador' e 'Equipe' voltem a ser colunas normais (se necessário)
db_agrupado.reset_index(inplace=True)

db_agrupado = db_agrupado[(db_agrupado['Aparicoes']>6) & (db_agrupado['Total_Gols'] > 2)]

# %%
db_agrupado = db_agrupado[(db_agrupado['Aparicoes']>6) & (db_agrupado['Total_Gols'] > 2)]

# %%
db_agrupado
# Out:
#             Jogador       Equipe  Total_Gols  Total_Chutes  Aparicoes  \
# 0      Lionel Messi  Inter Miami          12            57         12
# 3       Luis Suárez  Inter Miami          16            52         20
# 4    Gabriel Chaves    LA Galaxy          10            89         26
# 7             Cucho         Crew          13            99         19
# 8      Carlos Gómez          RSL          13            66         22
# ..              ...          ...         ...           ...        ...
# 289     Rémi Walter  Sporting KC           3             6         14
# 325   Mohamed Farsi         Crew           3            10         22
# 342      Jake Davis  Sporting KC           3            14         23
# 350   Jon Gallagher       Austin           3             9         25
# 363    Teal Bunbury    Nashville           3            16         22
#
#      Total_Chutes_Gol  Média_Chutes_Total  Média_Chutes_Gol  Média_Gols
# 0                  25                4.75              2.08        1.00
# 3                  37                2.60              1.85        0.80
# 4                  39                3.42              1.50        0.38
# 7                  28                5.21              1.47        0.68
# 8                  32                3.00              1.45        0.59
# ..                ...                 ...               ...         ...
# 289                 3                0.43              0.21        0.21
# 325                 4                0.45              0.18        0.14
# 342                 4                0.61              0.17        0.13
# 350                 4                0.36              0.16        0.12
# 363                 3                0.73              0.14        0.14
#
# [145 rows x 9 columns]

# %%
times = db_agrupado['Equipe'].isin(['Portland Timbers','Rapids'])
db_agrupado[times]
# Out:
#                 Jogador            Equipe  Total_Gols  Total_Chutes  \
# 14   Jonathan Rodríguez  Portland Timbers          13            68
# 20              Evander  Portland Timbers          12            64
# 38       Rafael Navarro            Rapids          12            59
# 45          Felipe Mora  Portland Timbers          13            47
# 71   Djordje Mihailovic            Rapids          10            37
# 74         Cole Bassett            Rapids           8            60
# 102     Santiago Moreno  Portland Timbers           6            46
# 109        Kevin Cabral            Rapids           5            30
# 157              Antony  Portland Timbers           4            28
# 177       Calvin Harris            Rapids           3            17
#
#      Aparicoes  Total_Chutes_Gol  Média_Chutes_Total  Média_Chutes_Gol  \
# 14          22                29                3.09              1.32
# 20          22                26                2.91              1.18
# 38          26                26                2.27              1.00
# 45          22                20                2.14              0.91
# 71          21                16                1.76              0.76
# 74          26                19                2.31              0.73
# 102         25                15                1.84              0.60
# 109         21                12                1.43              0.57
# 157         26                11                1.08              0.42
# 177         24                 9                0.71              0.38
#
#      Média_Gols
# 14         0.59
# 20         0.55
# 38         0.46
# 45         0.59
# 71         0.48
# 74         0.31
# 102        0.24
# 109        0.24
# 157        0.15
# 177        0.12

# %%
database[database['Jogador'].isin(['Rafael Navarro'])]
# Out:
#        Equipe         Jogador    # Nação Pos.   Idade  Min.  Gols  Assis.  PB  \
# 144    Rapids  Rafael Navarro  9.0   BRA   FW  23-316    76     0       0   0
# 765    Rapids  Rafael Navarro  9.0   BRA   FW  23-323    71     0       0   0
# 1374   Rapids  Rafael Navarro  9.0   BRA   FW  23-337    90     0       0   0
# 1893   Rapids  Rafael Navarro  9.0   BRA   FW  23-344    69     0       0   0
# 2050   Rapids  Rafael Navarro  9.0   BRA   FW  23-351    90     0       0   0
# 2523   Rapids  Rafael Navarro  9.0   BRA   FW  23-358    84     1       0   1
# 3141   Rapids  Rafael Navarro  9.0   BRA   FW  23-365    84     2       1   1
# 3507   Rapids  Rafael Navarro  9.0   BRA   FW  24-006    79     0       0   0
# 3739   Rapids  Rafael Navarro  9.0   BRA   FW  24-013    90     0       0   0
# 4562   Rapids  Rafael Navarro  9.0   BRA   FW  24-021    89     1       0   0
# 4874   Rapids  Rafael Navarro  9.0   BRA   FW  24-027    90     1       0   0
# 5253   Rapids  Rafael Navarro  9.0   BRA   FW  24-031    80     1       0   1
# 5762   Rapids  Rafael Navarro  9.0   BRA   FW  24-034    70     1       0   0
# 6118   Rapids  Rafael Navarro  9.0   BRA   FW  24-041    90     1       0   0
# 6488   Rapids  Rafael Navarro  9.0   BRA   FW  24-045    69     0       0   0
# 6931   Rapids  Rafael Navarro  9.0   BRA   FW  24-048    22     0       0   0
# 7552   Rapids  Rafael Navarro  9.0   BRA   FW  24-062    85     1       0   0
# 7897   Rapids  Rafael Navarro  9.0   BRA   FW  24-066    81     0       0   0
# 8282   Rapids  Rafael Navarro  9.0   BRA   FW  24-069    89     1       0   0
# 8573   Rapids  Rafael Navarro  9.0   BRA   FW  24-076    75     0       0   0
# 9162   Rapids  Rafael Navarro  9.0   BRA   FW  24-081    90     0       0   0
# 9529   Rapids  Rafael Navarro  9.0   BRA   FW  24-084    82     0       0   0
# 9968   Rapids  Rafael Navarro  9.0   BRA   FW  24-090    90     0       0   0
# 10412  Rapids  Rafael Navarro  9.0   BRA   FW  24-094    74     0       0   0
# 10826  Rapids  Rafael Navarro  9.0   BRA   FW  24-097    88     0       0   0
# 11554  Rapids  Rafael Navarro  9.0   BRA   FW  24-139    90     2       0   0
#
#        PT  TC  CaG  CrtsA  CrtV  Contatos  Div  Crts  Bloqueios   xG  npxG  \
# 144     0   2    1      0     0        32    2     1          2  0.1   0.1
# 765     0   1    0      0     0        21    1     0          1  0.1   0.1
# 1374    0   2    1      0     0        34    2     0          2  0.1   0.1
# 1893    0   1    0      0     0        26    2     0          1  0.0   0.0
# 2050    0   0    0      1     0        37    3     0          1  0.0   0.0
# 2523    1   0    0      1     0        38    0     0          4  0.8   0.0
# 3141    1   2    1      0     0        46    4     0          1  1.1   0.3
# 3507    0   2    1      0     0        39    0     1          1  0.3   0.3
# 3739    0   3    1      0     0        37    0     1          1  0.2   0.2
# 4562    0   2    1      0     0        50    3     2          3  0.1   0.1
# 4874    0   4    2      1     0        31    1     0          1  0.5   0.5
# 5253    1   3    1      0     0        28    2     0          0  1.3   0.5
# 5762    0   3    2      0     0        32    2     0          2  0.8   0.8
# 6118    1   3    3      0     0        45    1     0          2  1.1   0.3
# 6488    1   3    2      0     0        16    0     0          0  0.9   0.1
# 6931    0   1    0      0     0        14    1     0          1  0.0   0.0
# 7552    0   4    2      0     0        35    2     0          1  0.4   0.4
# 7897    0   1    0      0     0        35    3     0          2  0.1   0.1
# 8282    0   3    1      0     0        46    2     1          2  0.3   0.3
# 8573    0   2    0      1     0        36    4     0          1  0.1   0.1
# 9162    0   3    1      0     0        29    0     0          3  1.0   1.0
# 9529    0   2    1      0     0        32    0     0          1  0.1   0.1
# 9968    0   5    0      0     0        28    0     0          0  1.3   1.3
# 10412   1   2    2      0     0        28    0     1          2  0.9   0.1
# 10826   0   2    0      0     0        27    2     0          1  0.1   0.1
# 11554   0   3    3      1     0        27    3     0          1  1.3   0.6
#
#        xAG  SCA  GCA  Cmp  Att  Cmp%  PrgP  Conduções  PrgC  Tent  Suc  \
# 144    0.0    2    0   14   19  73,7     3         15     0     4    2
# 765    0.0    0    0    8   10  80,0     0         10     0     1    0
# 1374   0.0    2    0   12   20  60,0     1         17     2     3    2
# 1893   0.0    1    0    5   14  35,7     0         11     1     3    1
# 2050   0.0    2    2   16   23  69,6     0         20     3     5    3
# 2523   0.0    0    0   19   27  70,4     0         22     3     5    4
# 3141   0.2    5    2   20   27  74,1     1         22     3     7    2
# 3507   0.3    4    0   22   26  84,6     3         25     3     3    1
# 3739   0.0    1    0   15   25  60,0     2         24     1     3    2
# 4562   0.1    3    1   22   33  66,7     6         25     1     1    0
# 4874   0.0    2    0   16   20  80,0     1         20     3     6    5
# 5253   0.2    2    0   13   18  72,2     1         14     0     0    0
# 5762   0.1    3    1   12   20  60,0     1         24     2     3    2
# 6118   0.0    2    1   21   31  67,7     2         20     0     4    0
# 6488   0.0    4    1    5    9  55,6     2          7     2     2    2
# 6931   0.0    0    0    7    8  87,5     1          8     1     0    0
# 7552   0.0    1    0   17   18  94,4     2         22     3     5    2
# 7897   0.1    4    0   16   20  80,0     4         16     0     6    2
# 8282   0.0    3    0   23   32  71,9     3         30     2     4    1
# 8573   0.0    3    0   16   21  76,2     4         26     0     7    4
# 9162   0.0    1    0   14   20  70,0     1         15     3     0    0
# 9529   0.2    5    1   12   20  60,0     4         26     1     7    3
# 9968   0.3    7    0   11   18  61,1     3         15     1     3    3
# 10412  0.0    3    1   11   16  68,8     4         12     0     2    1
# 10826  0.1    2    1   10   16  62,5     2         18     1     1    0
# 11554  0.0    2    1    8   14  57,1     2         13     0     2    0
#
#              Data
# 144    2024-02-24
# 765    2024-03-02
# 1374   2024-03-16
# 1893   2024-03-23
# 2050   2024-03-30
# 2523   2024-04-06
# 3141   2024-04-13
# 3507   2024-04-20
# 3739   2024-04-27
# 4562   2024-05-05
# 4874   2024-05-11
# 5253   2024-05-15
# 5762   2024-05-18
# 6118   2024-05-25
# 6488   2024-05-29
# 6931   2024-06-01
# 7552   2024-06-15
# 7897   2024-06-19
# 8282   2024-06-22
# 8573   2024-06-29
# 9162   2024-07-04
# 9529   2024-07-07
# 9968   2024-07-13
# 10412  2024-07-17
# 10826  2024-07-20
# 11554  2024-08-31

# %% [markdown]
# # Agrupado por Equipe

# %%
agrupado_time = database.groupby(['Equipe']).agg(
    Total_Gols_Time = ('Gols','sum'),
    Total_Chutes_Time = ('TC','sum'),
    Total_Chutes_Gol_Time = ('CaG','sum'),
    Total_Jogos = ('Data','nunique')
)

agrupado_time['Média_Gols']= round(agrupado_time['Total_Gols_Time'] / agrupado_time['Total_Jogos'],2)
agrupado_time['Média_Chutes']= round(agrupado_time['Total_Chutes_Time'] / agrupado_time['Total_Jogos'],2)
agrupado_time['Média_Chutes_Gols']= round(agrupado_time['Total_Chutes_Gol_Time'] / agrupado_time['Total_Jogos'],2)

agrupado_time.sort_values(by='Média_Chutes_Gols', ascending= False)
# Out:
#                   Total_Gols_Time  Total_Chutes_Time  Total_Chutes_Gol_Time  \
# Equipe
# LAFC                           47                391                    147
# LA Galaxy                      52                375                    149
# Inter Miami                    61                317                    144
# FC Cincinnati                  48                387                    146
# NY Red Bulls                   42                411                    143
# RSL                            50                399                    139
# Philadelphia                   49                419                    140
# Atlanta Utd                    35                399                    130
# Minnesota Utd                  43                337                    125
# Rapids                         47                327                    120
# NYCFC                          40                362                    122
# Dynamo FC                      35                377                    129
# D.C. United                    43                382                    124
# Seattle                        39                370                    121
# Portland Timbers               55                363                    134
# Orlando City                   39                350                    114
# NE Revolution                  30                290                    112
# Fire                           37                362                    128
# Vancouver W'caps               43                317                    106
# Sporting KC                    45                345                    109
# Crew                           51                376                    128
# Toronto FC                     33                301                    109
# Charlotte                      30                289                    104
# FC Dallas                      44                341                    121
# SJ Earthquakes                 32                338                    100
# St. Louis                      33                383                    110
# Nashville                      25                299                     85
# Austin                         30                238                     72
# CF Montréal                    28                272                     78
#
#                   Total_Jogos  Média_Gols  Média_Chutes  Média_Chutes_Gols
# Equipe
# LAFC                       25        1.88         15.64               5.88
# LA Galaxy                  27        1.93         13.89               5.52
# Inter Miami                27        2.26         11.74               5.33
# FC Cincinnati              28        1.71         13.82               5.21
# NY Red Bulls               28        1.50         14.68               5.11
# RSL                        28        1.79         14.25               4.96
# Philadelphia               29        1.69         14.45               4.83
# Atlanta Utd                27        1.30         14.78               4.81
# Minnesota Utd              27        1.59         12.48               4.63
# Rapids                     26        1.81         12.58               4.62
# NYCFC                      27        1.48         13.41               4.52
# Dynamo FC                  29        1.21         13.00               4.45
# D.C. United                28        1.54         13.64               4.43
# Seattle                    28        1.39         13.21               4.32
# Portland Timbers           31        1.77         11.71               4.32
# Orlando City               27        1.44         12.96               4.22
# NE Revolution              27        1.11         10.74               4.15
# Fire                       31        1.19         11.68               4.13
# Vancouver W'caps           26        1.65         12.19               4.08
# Sporting KC                27        1.67         12.78               4.04
# Crew                       32        1.59         11.75               4.00
# Toronto FC                 28        1.18         10.75               3.89
# Charlotte                  27        1.11         10.70               3.85
# FC Dallas                  32        1.38         10.66               3.78
# SJ Earthquakes             27        1.19         12.52               3.70
# St. Louis                  32        1.03         11.97               3.44
# Nashville                  28        0.89         10.68               3.04
# Austin                     27        1.11          8.81               2.67
# CF Montréal                33        0.85          8.24               2.36

# %% [markdown]
# # Agrupado por Data

# %%
agrupado_data = database.groupby(['Equipe','Data']).agg(
    Total_Gols_Time = ('Gols','sum'),
    Total_Chutes_Time = ('TC','sum'),
    Total_Chutes_Gol_Time = ('CaG','sum'),
    Total_Jogos = ('Data','nunique')
)

agrupado_data['Média_Gols']= round(agrupado_data['Total_Gols_Time'] / agrupado_data['Total_Jogos'],2)
agrupado_data['Média_Chutes']= round(agrupado_data['Total_Chutes_Time'] / agrupado_data['Total_Jogos'],2)
agrupado_data['Média_Chutes_Gols']= round(agrupado_data['Total_Chutes_Gol_Time'] / agrupado_data['Total_Jogos'],2)

agrupado_data.sort_values(by='Média_Chutes_Gols', ascending= False)

agrupado_data.reset_index(inplace=True)

agrupado_data
# Out:
#                Equipe        Data  Total_Gols_Time  Total_Chutes_Time  \
# 0         Atlanta Utd  2024-02-24                0                  8
# 1         Atlanta Utd  2024-03-09                4                 19
# 2         Atlanta Utd  2024-03-17                2                 13
# 3         Atlanta Utd  2024-03-23                0                  8
# 4         Atlanta Utd  2024-03-31                3                 21
# ..                ...         ...              ...                ...
# 814  Vancouver W'caps  2024-07-13                4                 13
# 815  Vancouver W'caps  2024-07-17                1                 14
# 816  Vancouver W'caps  2024-07-20                3                 15
# 817  Vancouver W'caps  2024-08-31                1                 18
# 818  Vancouver W'caps  2024-09-07                0                 17
#
#      Total_Chutes_Gol_Time  Total_Jogos  Média_Gols  Média_Chutes  \
# 0                        2            1         0.0           8.0
# 1                        7            1         4.0          19.0
# 2                        7            1         2.0          13.0
# 3                        3            1         0.0           8.0
# 4                        7            1         3.0          21.0
# ..                     ...          ...         ...           ...
# 814                      9            1         4.0          13.0
# 815                      4            1         1.0          14.0
# 816                      6            1         3.0          15.0
# 817                      4            1         1.0          18.0
# 818                      3            1         0.0          17.0
#
#      Média_Chutes_Gols
# 0                  2.0
# 1                  7.0
# 2                  7.0
# 3                  3.0
# 4                  7.0
# ..                 ...
# 814                9.0
# 815                4.0
# 816                6.0
# 817                4.0
# 818                3.0
#
# [819 rows x 9 columns]

# %%
agrupado_data[agrupado_data['Equipe'].isin(['NY Red Bulls'])]
# Out:
#            Equipe        Data  Total_Gols_Time  Total_Chutes_Time  \
# 427  NY Red Bulls  2024-02-25                0                 18
# 428  NY Red Bulls  2024-03-02                2                 12
# 429  NY Red Bulls  2024-03-09                2                 17
# 430  NY Red Bulls  2024-03-16                0                  3
# 431  NY Red Bulls  2024-03-23                4                 12
# 432  NY Red Bulls  2024-03-30                1                  6
# 433  NY Red Bulls  2024-04-06                2                 10
# 434  NY Red Bulls  2024-04-13                0                 19
# 435  NY Red Bulls  2024-04-20                1                  8
# 436  NY Red Bulls  2024-04-27                1                 16
# 437  NY Red Bulls  2024-05-04                2                 14
# 438  NY Red Bulls  2024-05-11                4                 12
# 439  NY Red Bulls  2024-05-15                4                 11
# 440  NY Red Bulls  2024-05-18                1                 15
# 441  NY Red Bulls  2024-05-29                3                 12
# 442  NY Red Bulls  2024-06-01                1                 13
# 443  NY Red Bulls  2024-06-08                0                 15
# 444  NY Red Bulls  2024-06-15                0                 21
# 445  NY Red Bulls  2024-06-19                2                 26
# 446  NY Red Bulls  2024-06-22                3                 14
# 447  NY Red Bulls  2024-06-29                2                 22
# 448  NY Red Bulls  2024-07-06                0                 16
# 449  NY Red Bulls  2024-07-13                1                 13
# 450  NY Red Bulls  2024-07-17                1                 15
# 451  NY Red Bulls  2024-07-20                3                 19
# 452  NY Red Bulls  2024-08-24                1                 20
# 453  NY Red Bulls  2024-08-31                0                 21
# 454  NY Red Bulls  2024-09-07                1                 11
#
#      Total_Chutes_Gol_Time  Total_Jogos  Média_Gols  Média_Chutes  \
# 427                      5            1         0.0          18.0
# 428                      5            1         2.0          12.0
# 429                      8            1         2.0          17.0
# 430                      2            1         0.0           3.0
# 431                      6            1         4.0          12.0
# 432                      1            1         1.0           6.0
# 433                      4            1         2.0          10.0
# 434                      5            1         0.0          19.0
# 435                      2            1         1.0           8.0
# 436                      9            1         1.0          16.0
# 437                      4            1         2.0          14.0
# 438                      5            1         4.0          12.0
# 439                      7            1         4.0          11.0
# 440                      4            1         1.0          15.0
# 441                      6            1         3.0          12.0
# 442                      4            1         1.0          13.0
# 443                      5            1         0.0          15.0
# 444                      6            1         0.0          21.0
# 445                      9            1         2.0          26.0
# 446                      7            1         3.0          14.0
# 447                      3            1         2.0          22.0
# 448                      5            1         0.0          16.0
# 449                      7            1         1.0          13.0
# 450                      6            1         1.0          15.0
# 451                      8            1         3.0          19.0
# 452                      3            1         1.0          20.0
# 453                      4            1         0.0          21.0
# 454                      3            1         1.0          11.0
#
#      Média_Chutes_Gols
# 427                5.0
# 428                5.0
# 429                8.0
# 430                2.0
# 431                6.0
# 432                1.0
# 433                4.0
# 434                5.0
# 435                2.0
# 436                9.0
# 437                4.0
# 438                5.0
# 439                7.0
# 440                4.0
# 441                6.0
# 442                4.0
# 443                5.0
# 444                6.0
# 445                9.0
# 446                7.0
# 447                3.0
# 448                5.0
# 449                7.0
# 450                6.0
# 451                8.0
# 452                3.0
# 453                4.0
# 454                3.0

# %%
database['Equipe'].unique()
# Out:
# array(['Inter Miami', 'FC Cincinnati', 'RSL', 'Portland Timbers',
#        'NE Revolution', 'Crew', 'LAFC', 'Atlanta Utd', 'Seattle',
#        'SJ Earthquakes', 'Charlotte', 'FC Dallas', 'Fire', 'CF Montréal',
#        'D.C. United', 'Philadelphia', 'Rapids', 'St. Louis', 'Austin',
#        'Orlando City', 'Minnesota Utd', 'Dynamo FC', 'Sporting KC',
#        'NYCFC', 'Toronto FC', 'NY Red Bulls', 'Nashville', 'LA Galaxy',
#        "Vancouver W'caps", nan], dtype=object)
