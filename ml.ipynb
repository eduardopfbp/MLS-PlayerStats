# %% [markdown]
# # Importando Bibliotecas e opções

# %%
import pandas as pd
import matplotlib.pyplot as plt
import tkinter as tk
import numpy as np
from skimpy import skim
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Analisando os Dados

# %%
data = 'C://Users//eduar//Desktop//DEV//Football//MLS//database.csv'
database = pd.read_csv(data)
agrupado_01 = round(database.groupby('Jogador').agg({'Jogador': 'count'}),2)
agrupado_01.rename(columns={'Jogador':'Nº de Jogos'}, inplace= True)
agrupado_01.sort_values(by='Nº de Jogos', ascending= False, inplace= True)

parametro_01 = agrupado_01[agrupado_01['Nº de Jogos']>6].index

database_ml = database[database['Jogador'].isin(parametro_01)]

# %%
database_ml
# Out:
#                     Jogador                 Time   # Nação   Pos.   Idade  \
# 0               Luis Suárez          Inter Miami   9   URU     FW  37-028
# 1          Leonardo Campana          Inter Miami   8   ECU     FW  23-212
# 2             Robert Taylor          Inter Miami  16   FIN     LW  29-123
# 3                David Ruiz          Inter Miami  41   HON     RM  20-013
# 4              Lionel Messi          Inter Miami  10   ARG  RW,FW  36-242
# ...                     ...                  ...  ..   ...    ...     ...
# 14547              Jon Bell  Seattle Sounders FC  15   JAM     LB  27-037
# 14548         Jackson Ragen  Seattle Sounders FC  25   USA     CB  26-008
# 14549  Yeimar Gómez Andrade  Seattle Sounders FC  28   COL     CB  32-094
# 14550           Alex Roldan  Seattle Sounders FC  16   SLV     RB  28-066
# 14551           Stefan Frei  Seattle Sounders FC  24   SUI     GK  38-165
#
#        Min.  Gols  Assis.  PB  PT  TC  CaG  CrtsA  CrtV  Contatos  Div  Crts  \
# ...

# %%
database_ml[database_ml['Jogador']=='Luis Suárez']
# Out:
#            Jogador         Time  # Nação Pos.   Idade  Min.  Gols  Assis.  PB  \
# 0      Luis Suárez  Inter Miami  9   URU   FW  37-028    89     0       1   0
# 432    Luis Suárez  Inter Miami  9   URU   FW  37-032    66     0       0   0
# 507    Luis Suárez  Inter Miami  9   URU   FW  37-038    66     2       2   0
# 988    Luis Suárez  Inter Miami  9   URU   CM  37-046    14     0       0   0
# 1336   Luis Suárez  Inter Miami  9   URU   LW  37-052    29     2       0   0
# 1695   Luis Suárez  Inter Miami  9   URU   FW  37-059    90     0       0   0
# 2155   Luis Suárez  Inter Miami  9   URU   FW  37-066    90     1       0   0
# 3278   Luis Suárez  Inter Miami  9   URU   FW  37-080    90     1       0   0
# 3471   Luis Suárez  Inter Miami  9   URU   FW  37-087    87     0       1   0
# 3944   Luis Suárez  Inter Miami  9   URU   FW  37-094    27     1       0   0
# 4232   Luis Suárez  Inter Miami  9   URU   FW  37-101    83     3       1   0
# ...

# %%
numeric_ = database_ml.select_dtypes(include=[float,int])
x = numeric_.corr()
x['CaG'].sort_values(ascending=False)
# Out:
# CaG          1.000000
# TC           0.699066
# npxG         0.629910
# Gols         0.614544
# xG           0.604020
# SCA          0.332872
# Tent         0.283036
# PrgC         0.281382
# Suc          0.224809
# GCA          0.205038
# xAG          0.187099
# Min.         0.132590
# PrgP         0.107868
# Assis.       0.106522
# PT           0.093834
# Conduções    0.068595
# PB           0.062466
# Contatos     0.029151
# CrtsA        0.014997
# CrtV         0.003260
# Bloqueios   -0.008855
# Div         -0.010592
# Att         -0.024183
# #           -0.037841
# Cmp         -0.042050
# Crts        -0.052486
# Name: CaG, dtype: float64

# %%
# Passo 1: Obter a matriz de correlação
correlation_matrix = numeric_.corr()

# Passo 2: Transformar a matriz em formato "long" e remover duplicatas (pares repetidos)
correlation_pairs = correlation_matrix.unstack().reset_index()
correlation_pairs.columns = ['Variable 1', 'Variable 2', 'Correlation']

# Passo 3: Remover as correlações de uma variável com ela mesma
correlation_pairs = correlation_pairs[correlation_pairs['Variable 1'] != correlation_pairs['Variable 2']]

# Passo 4: Ordenar pelos valores absolutos das correlações
correlation_pairs['Abs Correlation'] = correlation_pairs['Correlation'].abs()
strongest_correlations = correlation_pairs.sort_values(by='Abs Correlation', ascending=False)

# Exibir as correlações mais fortes
strongest_correlations.head
# Out:
#     Variable 1 Variable 2  Correlation  Abs Correlation
# 530        Att   Contatos     0.986033         0.986033
# 280   Contatos        Att     0.986033         0.986033
# 539        Att        Cmp     0.984879         0.984879
# 514        Cmp        Att     0.984879         0.984879
# 504        Cmp   Contatos     0.965742         0.965742
# 279   Contatos        Cmp     0.965742         0.965742
# 542        Att  Conduções     0.928076         0.928076
# 592  Conduções        Att     0.928076         0.928076
# 582  Conduções   Contatos     0.927274         0.927274
# 282   Contatos  Conduções     0.927274         0.927274

# %%
# Substitua 'Nome do Jogador X' pelo nome real do jogador desejado
jogador_selecionado = "Christian Benteke"

# Filtrando o DataFrame para o jogador escolhido
dados_jogador = database_ml[database_ml['Jogador'] == jogador_selecionado]

# Selecionando as variáveis para o modelo
X = dados_jogador[['xG','Gols','npxG','TC']]
y = dados_jogador['CaG']

# Dividindo o conjunto de dados em treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Criando o modelo de regressão linear
modelo = LinearRegression()
modelo.fit(X_train, y_train)

# Criando um DataFrame com os últimos 5 jogos como valores para previsão
dados_treino = dados_jogador[len(dados_jogador) - 5:len(dados_jogador)][['xG','Gols','npxG','TC']]

# Tirando a média dos últimos 5 jogos para previsão e fazendo a Transposição dos dados
dados_treino_media = pd.DataFrame(dados_treino.mean()).transpose()

# Fazendo a previsão para o próximo jogo
pontuacao_proximo_jogo = modelo.predict(X_test).round(2)

# Fazendo a previsão2 para o próximo jogo
pontuacao_proximo_jogo2 = modelo.predict(dados_treino_media).round(2)

# Calculando o MAE para as previsões
mae_proximo_jogo = mean_absolute_error(y_test, pontuacao_proximo_jogo)

# Calculando o MAE para as previsões2
mae_proximo_jogo2 = mean_absolute_error([y_test.mean()], pontuacao_proximo_jogo2)

std_pts = round(pontuacao_proximo_jogo.std(),2)

std_player = round(y.std(),2)

# Calculando o R² para as previsões
r2_proximo_jogo= r2_score(y_test, pontuacao_proximo_jogo)



print(f"Média de pontuação do jogador {jogador_selecionado}: {dados_jogador['Gols'].mean().__round__(2)} pontos\n" )

print(f"Desvio padrão de pontos do jogador {jogador_selecionado}: {std_player} pontos\n")

print(100*"*","\n")

print('Teste com os dados:\n')

#print(f"Previsão de pontuação para o próximo jogo do jogador {jogador_selecionado}: {pontuacao_proximo_jogo} pontos\n" )

#print(f"Pontos que foram utilizados para Test_y {jogador_selecionado}: {y_test} pontos\n" )

print(f"Média da previsão de pontuação para o próximo jogo do jogador {jogador_selecionado}: {round(pontuacao_proximo_jogo.mean(),2)} pontos\n" )

print(f"Coeficiente de Determinação (R²) para o próximo jogo do jogador {jogador_selecionado}: {r2_proximo_jogo:.2f}\n")

print(f"Erro Médio Absoluto para o próximo jogo do jogador {jogador_selecionado}: {mae_proximo_jogo:.2f} pontos \n")

print(f"Desvio padrão da previsão do jogador {jogador_selecionado}: {std_pts} pontos\n")

print(100*"*","\n")

print('Teste com a média dos últimos 5 jogos:\n')

print(f"Previsão de pontuação para o próximo jogo do jogador {jogador_selecionado}: {float(pontuacao_proximo_jogo2)} pontos\n" )

print(f"Erro Médio Absoluto para o próximo jogo do jogador {jogador_selecionado}: {float(mae_proximo_jogo2):.2f} pontos \n")

print(100*"*","\n")



dados_jogador.tail(10)
# Out:
# Média de pontuação do jogador Christian Benteke: 0.79 pontos
#
# Desvio padrão de pontos do jogador Christian Benteke: 1.16 pontos
#
# ****************************************************************************************************
#
# Teste com os dados:
#
# Média da previsão de pontuação para o próximo jogo do jogador Christian Benteke: 1.42 pontos
#
# Coeficiente de Determinação (R²) para o próximo jogo do jogador Christian Benteke: 0.80
#
# Erro Médio Absoluto para o próximo jogo do jogador Christian Benteke: 0.54 pontos
#
# Desvio padrão da previsão do jogador Christian Benteke: 1.33 pontos
#
# ****************************************************************************************************
#
# Teste com a média dos últimos 5 jogos:
#
# Previsão de pontuação para o próximo jogo do jogador Christian Benteke: 1.41 pontos
#
# Erro Médio Absoluto para o próximo jogo do jogador Christian Benteke: 0.19 pontos
#
# ...

# %% [markdown]
# # Agrupado por Jogador

# %%
# Agrupar os dados por jogador e Time, e calcular as somas e contagens necessárias
db_agrupado = database.groupby(['Jogador', 'Time']).agg(
    Total_Gols=('Gols', 'sum'),           # Soma de gols
    Total_Chutes=('TC', 'sum'),           # Soma dos chutes totais (presumo que TC significa 'Total Chutes')
    Aparicoes=('Jogador', 'count'),       # Contagem de aparições
    Total_Chutes_Gol=('CaG', 'sum')       # Soma dos chutes ao gol (CaG = Chutes ao Gol)
)

# Calcular as médias: chute total, chute ao gol e gols por aparição
db_agrupado['Média_Chutes_Total'] = round(db_agrupado['Total_Chutes'] / db_agrupado['Aparicoes'], 2)
db_agrupado['Média_Chutes_Gol'] = round(db_agrupado['Total_Chutes_Gol'] / db_agrupado['Aparicoes'], 2)
db_agrupado['Média_Gols'] = round(db_agrupado['Total_Gols'] / db_agrupado['Aparicoes'], 2)

# Ordenar o DataFrame pela média de chutes ao gol, de forma decrescente
db_agrupado.sort_values(by='Média_Chutes_Gol', ascending=False, inplace=True)

# Resetar o índice para que 'Jogador' e 'Time' voltem a ser colunas normais (se necessário)
db_agrupado.reset_index(inplace=True)

db_agrupado = db_agrupado[(db_agrupado['Aparicoes']>6) & (db_agrupado['Total_Gols'] > 2)]

# %%
db_agrupado = db_agrupado[(db_agrupado['Aparicoes']>6) & (db_agrupado['Total_Gols'] > 2)]

# %%
db_agrupado.sort_values(by='Total_Gols', ascending= False)
# Out:
#                Jogador                 Time  Total_Gols  Total_Chutes  \
# 11   Christian Benteke          D.C. United          22            85
# 8        Denis Bouanga       Los Angeles FC          19           137
# 4          Luis Suárez          Inter Miami          18            64
# 30       Dániel Gazdag   Philadelphia Union          18            45
# 14               Cucho        Columbus Crew          18           118
# ..                 ...                  ...         ...           ...
# 198        Corey Baird        FC Cincinnati           3            18
# 213     Griffin Dorsey       Houston Dynamo           3            37
# 217       Iuri Tavares         Charlotte FC           3            26
# 219     Kervin Arriaga     Minnesota United           3            16
# 467      Jackson Ragen  Seattle Sounders FC           3            23
#
#      Aparicoes  Total_Chutes_Gol  Média_Chutes_Total  Média_Chutes_Gol  \
# ...

# %%
times = db_agrupado['Equipe'].isin(['Portland Timbers','Rapids'])
db_agrupado[times]
# Out:
#                 Jogador            Equipe  Total_Gols  Total_Chutes  \
# 14   Jonathan Rodríguez  Portland Timbers          13            68
# 20              Evander  Portland Timbers          12            64
# 38       Rafael Navarro            Rapids          12            59
# 45          Felipe Mora  Portland Timbers          13            47
# 71   Djordje Mihailovic            Rapids          10            37
# 74         Cole Bassett            Rapids           8            60
# 102     Santiago Moreno  Portland Timbers           6            46
# 109        Kevin Cabral            Rapids           5            30
# 157              Antony  Portland Timbers           4            28
# 177       Calvin Harris            Rapids           3            17
#
#      Aparicoes  Total_Chutes_Gol  Média_Chutes_Total  Média_Chutes_Gol  \
# 14          22                29                3.09              1.32
# 20          22                26                2.91              1.18
# ...

# %%
database[database['Jogador'].isin(['Rafael Navarro'])]
# Out:
#        Equipe         Jogador    # Nação Pos.   Idade  Min.  Gols  Assis.  PB  \
# 144    Rapids  Rafael Navarro  9.0   BRA   FW  23-316    76     0       0   0
# 765    Rapids  Rafael Navarro  9.0   BRA   FW  23-323    71     0       0   0
# 1374   Rapids  Rafael Navarro  9.0   BRA   FW  23-337    90     0       0   0
# 1893   Rapids  Rafael Navarro  9.0   BRA   FW  23-344    69     0       0   0
# 2050   Rapids  Rafael Navarro  9.0   BRA   FW  23-351    90     0       0   0
# 2523   Rapids  Rafael Navarro  9.0   BRA   FW  23-358    84     1       0   1
# 3141   Rapids  Rafael Navarro  9.0   BRA   FW  23-365    84     2       1   1
# 3507   Rapids  Rafael Navarro  9.0   BRA   FW  24-006    79     0       0   0
# 3739   Rapids  Rafael Navarro  9.0   BRA   FW  24-013    90     0       0   0
# 4562   Rapids  Rafael Navarro  9.0   BRA   FW  24-021    89     1       0   0
# 4874   Rapids  Rafael Navarro  9.0   BRA   FW  24-027    90     1       0   0
# ...

# %% [markdown]
# # Agrupado por Equipe

# %%
agrupado_time = database.groupby(['Equipe']).agg(
    Total_Gols_Time = ('Gols','sum'),
    Total_Chutes_Time = ('TC','sum'),
    Total_Chutes_Gol_Time = ('CaG','sum'),
    Total_Jogos = ('Data','nunique')
)

agrupado_time['Média_Gols']= round(agrupado_time['Total_Gols_Time'] / agrupado_time['Total_Jogos'],2)
agrupado_time['Média_Chutes']= round(agrupado_time['Total_Chutes_Time'] / agrupado_time['Total_Jogos'],2)
agrupado_time['Média_Chutes_Gols']= round(agrupado_time['Total_Chutes_Gol_Time'] / agrupado_time['Total_Jogos'],2)

agrupado_time.sort_values(by='Média_Chutes_Gols', ascending= False)
# Out:
#                   Total_Gols_Time  Total_Chutes_Time  Total_Chutes_Gol_Time  \
# Equipe
# LAFC                           47                391                    147
# LA Galaxy                      52                375                    149
# Inter Miami                    61                317                    144
# FC Cincinnati                  48                387                    146
# NY Red Bulls                   42                411                    143
# RSL                            50                399                    139
# Philadelphia                   49                419                    140
# Atlanta Utd                    35                399                    130
# Minnesota Utd                  43                337                    125
# Rapids                         47                327                    120
# NYCFC                          40                362                    122
# ...

# %% [markdown]
# # Agrupado por Data

# %%
agrupado_data = database.groupby(['Equipe','Data']).agg(
    Total_Gols_Time = ('Gols','sum'),
    Total_Chutes_Time = ('TC','sum'),
    Total_Chutes_Gol_Time = ('CaG','sum'),
    Total_Jogos = ('Data','nunique')
)

agrupado_data['Média_Gols']= round(agrupado_data['Total_Gols_Time'] / agrupado_data['Total_Jogos'],2)
agrupado_data['Média_Chutes']= round(agrupado_data['Total_Chutes_Time'] / agrupado_data['Total_Jogos'],2)
agrupado_data['Média_Chutes_Gols']= round(agrupado_data['Total_Chutes_Gol_Time'] / agrupado_data['Total_Jogos'],2)

agrupado_data.sort_values(by='Média_Chutes_Gols', ascending= False)

agrupado_data.reset_index(inplace=True)

agrupado_data
# Out:
#                Equipe        Data  Total_Gols_Time  Total_Chutes_Time  \
# 0         Atlanta Utd  2024-02-24                0                  8
# 1         Atlanta Utd  2024-03-09                4                 19
# 2         Atlanta Utd  2024-03-17                2                 13
# 3         Atlanta Utd  2024-03-23                0                  8
# 4         Atlanta Utd  2024-03-31                3                 21
# ..                ...         ...              ...                ...
# 814  Vancouver W'caps  2024-07-13                4                 13
# 815  Vancouver W'caps  2024-07-17                1                 14
# 816  Vancouver W'caps  2024-07-20                3                 15
# 817  Vancouver W'caps  2024-08-31                1                 18
# 818  Vancouver W'caps  2024-09-07                0                 17
#
#      Total_Chutes_Gol_Time  Total_Jogos  Média_Gols  Média_Chutes  \
# ...

# %%
agrupado_data[agrupado_data['Equipe'].isin(['NY Red Bulls'])]
# Out:
#            Equipe        Data  Total_Gols_Time  Total_Chutes_Time  \
# 427  NY Red Bulls  2024-02-25                0                 18
# 428  NY Red Bulls  2024-03-02                2                 12
# 429  NY Red Bulls  2024-03-09                2                 17
# 430  NY Red Bulls  2024-03-16                0                  3
# 431  NY Red Bulls  2024-03-23                4                 12
# 432  NY Red Bulls  2024-03-30                1                  6
# 433  NY Red Bulls  2024-04-06                2                 10
# 434  NY Red Bulls  2024-04-13                0                 19
# 435  NY Red Bulls  2024-04-20                1                  8
# 436  NY Red Bulls  2024-04-27                1                 16
# 437  NY Red Bulls  2024-05-04                2                 14
# 438  NY Red Bulls  2024-05-11                4                 12
# 439  NY Red Bulls  2024-05-15                4                 11
# ...

# %%
database['Equipe'].unique()
# Out:
# array(['Inter Miami', 'FC Cincinnati', 'RSL', 'Portland Timbers',
#        'NE Revolution', 'Crew', 'LAFC', 'Atlanta Utd', 'Seattle',
#        'SJ Earthquakes', 'Charlotte', 'FC Dallas', 'Fire', 'CF Montréal',
#        'D.C. United', 'Philadelphia', 'Rapids', 'St. Louis', 'Austin',
#        'Orlando City', 'Minnesota Utd', 'Dynamo FC', 'Sporting KC',
#        'NYCFC', 'Toronto FC', 'NY Red Bulls', 'Nashville', 'LA Galaxy',
#        "Vancouver W'caps", nan], dtype=object)
